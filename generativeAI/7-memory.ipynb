# %%
import os

from langchain_groq import ChatGroq
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model = ChatGroq(model="qwen/qwen3-32b")

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

# %%
agent=create_agent(
    model="qwen/qwen3-32b",
    checkpointer=InMemorySaver()
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 agent=create_agent(
#       2     model="qwen/qwen3-32b",
#       3     checkpointer=InMemorySaver()
#       4 )
#
# File ~/Desktop/LangChain/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:832, in create_agent(model, tools, system_prompt, middleware, response_format, state_schema, context_schema, checkpointer, store, interrupt_before, interrupt_after, debug, name, cache)
#     830 # init chat model
#     831 if isinstance(model, str):
# --> 832     model = init_chat_model(model)
#     834 # Convert system_prompt to SystemMessage if needed
#     835 system_message: SystemMessage | None = None
#
# File ~/Desktop/LangChain/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:477, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     469     warnings.warn(
#     470         f"{config_prefix=} has been set but no fields are configurable. Set "
#     471         f"`configurable_fields=(...)` to specify the model params that are "
#     472         f"configurable.",
#     473         stacklevel=2,
#     474     )
#     476 if not configurable_fields:
# --> 477     return _init_chat_model_helper(
#     478         cast("str", model),
#     479         model_provider=model_provider,
#     480         **kwargs,
#     481     )
#     482 if model:
#     483     kwargs["model"] = model
#
# File ~/Desktop/LangChain/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:499, in _init_chat_model_helper(model, model_provider, **kwargs)
#     493 def _init_chat_model_helper(
#     494     model: str,
#     495     *,
#     496     model_provider: str | None = None,
#     497     **kwargs: Any,
#     498 ) -> BaseChatModel:
# --> 499     model, model_provider = _parse_model(model, model_provider)
#     500     creator_func = _get_chat_model_creator(model_provider)
#     501     return creator_func(model=model, **kwargs)
#
# File ~/Desktop/LangChain/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:595, in _parse_model(model, model_provider)
#     587     supported_list = ", ".join(sorted(_BUILTIN_PROVIDERS))
#     588     msg = (
#     589         f"Unable to infer model provider for {model=}. "
#     590         f"Please specify 'model_provider' directly.\n\n"
#    (...)    593         f"https://docs.langchain.com/oss/python/integrations/providers"
#     594     )
# --> 595     raise ValueError(msg)
#     597 # Normalize provider name
#     598 model_provider = model_provider.replace("-", "_").lower()
#
# ValueError: Unable to infer model provider for model='qwen/qwen3-32b'. Please specify 'model_provider' directly.
#
# Supported providers: anthropic, anthropic_bedrock, azure_ai, azure_openai, baseten, bedrock, bedrock_converse, cohere, deepseek, fireworks, google_anthropic_vertex, google_genai, google_vertexai, groq, huggingface, ibm, litellm, mistralai, nvidia, ollama, openai, openrouter, perplexity, together, upstage, xai
#
# For help with specific providers, see: https://docs.langchain.com/oss/python/integrations/providers
